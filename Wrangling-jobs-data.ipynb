# %% [markdown]
# # Wrangling the dataset
# ## Gather

# %%
import zipfile
import pandas as pd

# %%
# Extract all contents from zip file
with zipfile.ZipFile('armenian-online-job-postings.zip', 'r') as myzip:
    myzip.extractall()

# %%
df = pd.read_csv('online-job-postings.csv')
df.head(2)
# Out:
#                                              jobpost         date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...  Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...  Jan 7, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
#
#   Eligibility Audience StartDate  Duration  ...   Salary  \
# 0         NaN      NaN       NaN       NaN  ...      NaN
# 1         NaN      NaN       NaN  3 months  ...      NaN
#
#                                         ApplicationP OpeningDate  \
# 0  To apply for this position, please submit a\r\...         NaN
# 1  Please submit a cover letter and resume to:\r\...         NaN
#
# ...

# %% [markdown]
# ## Assess

# %%
df
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# 5      Boutique "Appollo"\r\nJOB TITLE:  Saleswoman\r...  Jan 10, 2004
# 6      OSI Assistance Foundation - Armenian Branch Of...  Jan 11, 2004
# 7      International Research & Exchanges Board (IREX...  Jan 13, 2004
# 8      Yerevan Brandy Company \r\nJOB TITLE:  Assista...  Jan 13, 2004
# 9      American Embassy Yerevan\r\nANNOUNCEMENT NUMBE...  Jan 13, 2004
# 10     International Research & Exchanges Board (IREX...  Jan 13, 2004
# 11     International Research & Exchanges Board (IREX...  Jan 13, 2004
# ...

# %%
df.StartDate.value_counts()
# Out:
# ASAP                                  4754
# Immediately                            773
# As soon as possible                    543
# Upon hiring                            261
# Immediate                              259
# Immediate employment                   140
# As soon as possible.                    32
# 01 September 2012                       31
# March 2006                              27
# November 2006                           22
# January 2010                            19
# 01 February 2005                        17
# Immediate job opportunity               17
# February 2014                           17
# February 2011                           16
# September 2010                          16
# TBD                                     16
# September 2008                          15
# March 2011                              15
# 01 July 2014                            14
# February 2007                           14
# 01 February 2015                        14
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19001 entries, 0 to 19000
# Data columns (total 24 columns):
# jobpost             19001 non-null object
# date                19001 non-null object
# Title               18973 non-null object
# Company             18994 non-null object
# AnnouncementCode    1208 non-null object
# Term                7676 non-null object
# Eligibility         4930 non-null object
# Audience            640 non-null object
# StartDate           9675 non-null object
# Duration            10798 non-null object
# Location            18969 non-null object
# JobDescription      15109 non-null object
# JobRequirment       16479 non-null object
# RequiredQual        18517 non-null object
# Salary              9622 non-null object
# ApplicationP        18941 non-null object
# OpeningDate         18295 non-null object
# Deadline            18936 non-null object
# Notes               2211 non-null object
# AboutC              12470 non-null object
# ...

# %% [markdown]
# #### Issues
# - start date inconsistent: Different ways of indicating ASAP independently such as 'as soon as possible', 'immediately', and 'some date or immediately'. convert all of them to 'ASAP'
# - Convert field names to descriptive ones. JobRequirment,ApplicationP, AboutC,RequiredQual
# ## Clean
# ### Issue 1: Start date
# #### Define
# - Extract a list of start date values that need to be replaced by 'ASAP'
# - Run a for loop over all the extracted values replaceing them.
#
# #### Code

# %%
# Checking initial values of start date
df.StartDate.value_counts()[-20:]
# Out:
# 01 March 2015 (preferably)            1
# 11 July 2004                          1
# 10 March 2011                         1
# 18 October 2010                       1
# 12 August 2013                        1
# November, 2007                        1
# 01 September  2009                    1
# 20 September 2006                     1
# 01 July 2006                          1
# January, 2009                         1
# 02 March 2009                         1
# 20 October 2008 - 03 December 2008    1
# 1 October 2007                        1
# 05 December 2005                      1
# 10 October 2014                       1
# Open                                  1
# 27 March 2008                         1
# Spring 2014                           1
# 07 June 2010                          1
# 10 June 2005                          1
# Name: StartDate, dtype: int64

# %%
# Creating a copy of the original df, to preserve original file
df_clean = df.copy()

# Create a list of values in start date that are synonimous to ASAP
asap_values = list(df_clean[df_clean.StartDate.fillna('').str.strip().str.lower().str.contains('immed') | \
df_clean.StartDate.fillna('').str.strip().str.lower().str.contains('soon') | \
df_clean.StartDate.fillna('').str.strip().str.lower().str.contains('upon hiring') | \
         df_clean.StartDate.fillna('').str.strip().str.lower().str.contains('open') | \
df_clean.StartDate.fillna('').str.strip().str.lower().str.contains('asap') ].StartDate.unique())#.StartDate.fillna('').unique()

# %%
len(asap_values) # number of values that need to be replaced
# Out:
# 45

# %%
# loop to replace all values in the df_clean dataset.
for value in asap_values:
    df_clean.StartDate.replace(value,'ASAP',inplace=True)

# %% [markdown]
# #### Test

# %%
df_clean.StartDate.value_counts().plot(kind='pie');

# %% [markdown]
# ### Issue 2: Rename non-descriptive column names
# #### Define
# - Convert field names to descriptive ones. JobRequirment,ApplicationP, AboutC,RequiredQual
# - convert: JobRequirment-JobRequirement, ApplicationP-ApplicationProcess, RequiredQual-RequiredQualification, AboutC-AboutCompany
# #### Code

# %%
replace_cols = { 'JobRequirment':'JobRequirement',
               'ApplicationP':'ApplicationProcess',
               'AboutC':'AboutCompany',
               'RequiredQual':'RequiredQualification'}
df_clean.rename(replace_cols,axis=1,inplace=True)

# %% [markdown]
# #### Test

# %%
df_clean.columns
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'AnnouncementCode', 'Term',
#        'Eligibility', 'Audience', 'StartDate', 'Duration', 'Location',
#        'JobDescription', 'JobRequirement', 'RequiredQualification', 'Salary',
#        'ApplicationProcess', 'OpeningDate', 'Deadline', 'Notes',
#        'AboutCompany', 'Attach', 'Year', 'Month', 'IT'],
#       dtype='object')
